# %%
from dotenv import load_dotenv
load_dotenv('../.env')

# %%
from langgraph_supervisor_with_agents.agents import SupervisorAgent

supervisor_agent = SupervisorAgent(
    model_name="openai:o4-mini",
    agents=[]
).get_supervisor()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 6
#       1 from langgraph_supervisor_with_agents.agents import SupervisorAgent
#       3 supervisor_agent = SupervisorAgent(
#       4     model_name="openai:o4-mini",
#       5     agents=[]
# ----> 6 ).get_supervisor()
#
# File ~/github-repos/langgraph-supervisor/src/langgraph_supervisor_with_agents/agents/supervisor.py:49, in SupervisorAgent.get_supervisor(self)
#      42 def get_supervisor(self):
#      43     """
#      44     Create a supervisor agent that manages multiple agents.
#      45
#      46     Returns:
#      47         Runnable: A runnable supervisor agent.
#      48     """
# ---> 49     model = init_chat_model(
#      50         model=self.model_name,
#      51         **self.model_kwargs)
#      52     if isinstance(model, str):
#      53         # Replace this with actual logic to load/instantiate a LanguageModelLike from a string
#      54         raise ValueError("model must be a LanguageModelLike instance, not a string. Please provide a valid model object.")
#
# File ~/.cache/pypoetry/virtualenvs/langgraph-supervisor-with-agents-xkMDjbS2-py3.12/lib/python3.12/site-packages/langchain/chat_models/base.py:322, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     315     warnings.warn(
#     316         f"{config_prefix=} has been set but no fields are configurable. Set "
#     317         f"`configurable_fields=(...)` to specify the model params that are "
#     318         f"configurable."
#     319     )
#     321 if not configurable_fields:
# --> 322     return _init_chat_model_helper(
#     323         cast(str, model), model_provider=model_provider, **kwargs
#     324     )
#     325 else:
#     326     if model:
#
# File ~/.cache/pypoetry/virtualenvs/langgraph-supervisor-with-agents-xkMDjbS2-py3.12/lib/python3.12/site-packages/langchain/chat_models/base.py:345, in _init_chat_model_helper(model, model_provider, **kwargs)
#     342     _check_pkg("langchain_openai")
#     343     from langchain_openai import ChatOpenAI
# --> 345     return ChatOpenAI(model=model, **kwargs)
#     346 elif model_provider == "anthropic":
#     347     _check_pkg("langchain_anthropic")
#
# File ~/.cache/pypoetry/virtualenvs/langgraph-supervisor-with-agents-xkMDjbS2-py3.12/lib/python3.12/site-packages/langchain_core/load/serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/.cache/pypoetry/virtualenvs/langgraph-supervisor-with-agents-xkMDjbS2-py3.12/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:743, in BaseChatOpenAI.validate_environment(self)
#     736         self.http_client = httpx.Client(
#     737             proxy=self.openai_proxy, verify=global_ssl_context
#     738         )
#     739     sync_specific = {
#     740         "http_client": self.http_client
#     741         or _get_default_httpx_client(self.openai_api_base, self.request_timeout)
#     742     }
# --> 743     self.root_client = openai.OpenAI(**client_params, **sync_specific)  # type: ignore[arg-type]
#     744     self.client = self.root_client.chat.completions
#     745 if not self.async_client:
#
# File ~/.cache/pypoetry/virtualenvs/langgraph-supervisor-with-agents-xkMDjbS2-py3.12/lib/python3.12/site-packages/openai/_client.py:130, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     128     api_key = os.environ.get("OPENAI_API_KEY")
#     129 if api_key is None:
# --> 130     raise OpenAIError(
#     131         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     132     )
#     133 self.api_key = api_key
#     135 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
